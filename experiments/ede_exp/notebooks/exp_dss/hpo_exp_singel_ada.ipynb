# %%
"""
ADABoost Experiments Serrano/AUDSOME Phase 1
Anomaly Only
Gabriel Iuhasz
"""
import numpy as np
np.random.seed(42)
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import balanced_accuracy_score, make_scorer, classification_report, accuracy_score, jaccard_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

import xgboost as xgb
# from sklearn.externals import joblib
from joblib import dump, load
import json
import os
import matplotlib.pyplot as plt
import seaborn as sns
from evolutionary_search import EvolutionaryAlgorithmSearchCV
from subprocess import check_output
# %matplotlib inline

# %%
def custom_scoring_reporting(y_pred,
                             y,
                             definitions,
                             prefix):
    """
    Custom function for handling scoring and reporting
    :param y_pred: model predictions
    :param y: ground truth
    :param definitions: variable class definitions (factorize)
    :param prefix: prefix to saved files and images
    :return: 0
    """
    print("Accuracy score is: {}".format(accuracy_score(y, y_pred)))
    print("Ballanced accuracy score is: {}".format(balanced_accuracy_score(y, y_pred)))
    print("Jaccard score (micro): {}".format(jaccard_score(y, y_pred, average='micro')))
    print("Jaccard score (macro): {}".format(jaccard_score(y, y_pred, average='macro')))
    print("Jaccard score (weighted): {}".format(jaccard_score(y, y_pred, average='weighted')))


    print("Full classification report")
    print(classification_report(y, y_pred, digits=4, target_names=definitions))
    report = classification_report(y, y_pred, digits=4, output_dict=True)
    df_classification_report = pd.DataFrame(report).transpose()
    classification_rep_name = "{}_classification_rep_best.csv".format(prefix)
    df_classification_report.to_csv(os.path.join(model_dir,classification_rep_name), index=False)


    print("Imbalanced Classification report")
    print(classification_report_imbalanced(y, y_pred, digits=4, target_names=definitions))
    imb_report = classification_report_imbalanced(y, y_pred, digits=4, target_names=definitions, output_dict=True)
    df_imb_classification_report = pd.DataFrame(imb_report).transpose()
    classification_imb_rep_name = "{}_imb_classification_rep_best.csv".format(prefix)
    df_imb_classification_report.to_csv(os.path.join(model_dir,classification_imb_rep_name), index=False)

# %% [markdown]
# Common preprocessing for all experiments

# %%
print("Checking files in data location ...")
# train_dir = '/Users/Gabriel/Dropbox/Research/ASPIDE/Datasets/ECI Chaos/Distributed Phase 1/finalized/single_node/training'
# train_dir = '/home/gabriel/Research/Aspide/workspace/data_phase'
train_dir = '/home/gabriel/research/dipet/serrano/data'
print(check_output(["ls", train_dir]).decode("utf8"))
# Out:
# Checking files in data location ...
# data
# df_anomaly.csv
# df_audsome.csv
# df_clean_ausdome_single.csv
# df_clean_single.csv
# models
# processed

# %%
print("Setting paths and datasets")
# Checking if directory exists for data, modells and processed

# data_dir = os.path.join(train_dir,'data')
model_dir = os.path.join(train_dir,'models')
# processed_dir = os.path.join(train_dir,'processed')
# if not os.path.exists(data_dir):
#     os.makedirs(data_dir)
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
# if not os.path.exists(processed_dir):
#     os.makedirs(processed_dir)
# Out:
# Setting paths and datasets

# %%
df_anomaly = pd.read_csv(os.path.join(train_dir,"df_anomaly.csv"))
df_audsome = pd.read_csv(os.path.join(train_dir,"df_audsome.csv"))
df_clean = pd.read_csv(os.path.join(train_dir,"df_clean_single.csv"))
df_clean_audsome = pd.read_csv(os.path.join(train_dir,"df_clean_ausdome_single.csv"))

# Set index as time
df_anomaly.set_index('time', inplace=True)
df_audsome.set_index('time', inplace=True)
df_clean.set_index('time', inplace=True)
df_clean_audsome.set_index('time', inplace=True)

# %%
print("Dataset chosen ...")
data = df_anomaly

# Nice print
nice_y = data['target']
data.shape
# Out:
# Dataset chosen ...
# (5400, 90)

# %%
# Uncomment for removing dummy TODO CHECK if adding back dummy
# data.loc[data.target == "dummy", 'target'] = "0"

#Creating the dependent variable class
factor = pd.factorize(data['target'])
data.target = factor[0]
definitions = factor[1]
# print(data.target.head())
# print(definitions)

# %%
print("Splitting dataset into training and ground truth ...")
X = data.drop('target', axis=1)
y = data['target']
# Out:
# Splitting dataset into training and ground truth ...

# %%
# Plot class distribution
print("Ploting class distribution ..")
pltdist= sns.countplot(nice_y)
pltdist.set_xticklabels(pltdist.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# Ploting class distribution ..

# %%
print("Scaling dataset")
# scaler = StandardScaler()
# scaler = RobustScaler()
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(X_scaled, index=X.index, columns=X.columns) # transform back to df
# Out:
# Scaling dataset

# %% [markdown]
# Starting of experiment for RandomForest only

# %%
# Name of experiment
# RandomForest
prefix = 'Phase1_ADA_evs'
paramgrid = {
    "n_estimators": [10, 50, 100, 200, 300, 500, 1000],
    "learning_rate": [1., 0.1, 0.01, 0.5, 0.7],
    "algorithm": ["SAMME", "SAMME.R"],
    "random_state": [42]
}
model = AdaBoostClassifier()
model.get_params().keys()
# Out:
# dict_keys(['algorithm', 'base_estimator', 'learning_rate', 'n_estimators', 'random_state'])

# %%
#Example of HPO methods https://github.com/LiYangHart/Hyperparameter-Optimization-of-Machine-Learning-Algorithms/blob/master/HPO_Classification.ipynb
# scorer = make_scorer(accuracy_score, )
scorer = make_scorer(jaccard_score, average="micro") # TODO check average
# scorer = 'accuracy'
n_splits = 4 # default 4

cv_type = StratifiedKFold(n_splits=n_splits)
nj = 10 # Number of jobs

cv = EvolutionaryAlgorithmSearchCV(estimator=model,
                                   params=paramgrid,
                                   scoring=scorer,
                                   cv=cv_type, # StratifiedKFold not supported for multilabel-indicator (oh encoding)
                                   verbose=4,
                                   population_size=40, # 40
                                   gene_mutation_prob=0.20,
                                   gene_crossover_prob=0.5,
                                   tournament_size=4,
                                   generations_number=30, #10
                                   n_jobs=nj) # for dnn n_jobs must be set to 1 rest is 8
# Out:
# /home/gabriel/anaconda3/envs/pyaspide/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /home/gabriel/anaconda3/envs/pyaspide/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)

# %%
cv.fit(X, y)
# Out:
# Types [1, 2, 1, 1] and maxint [6, 4, 1, 0] detected
# --- Evolve in 70 possible combinations ---
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.964 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.938 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.761 total time=   0.9s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.722 total time=   2.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.937 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.968 total time=   2.7s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.849 total time=   3.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.920 total time=  11.7s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.688 total time=   3.6s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.966 total time=   3.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=300, random_state=42;, score=0.915 total time=  16.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.931 total time=  17.3s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.988 total time=   2.3s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.754 total time=   1.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.884 total time=   9.7s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.964 total time=   2.5s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=500, random_state=42;, score=0.722 total time=  23.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=500, random_state=42;, score=0.929 total time=  24.2s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=500, random_state=42;, score=0.944 total time=  23.5s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=100, random_state=42;, score=0.930 total time=   5.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.735 total time=   9.5s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=100, random_state=42;, score=0.985 total time=   3.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.909 total time=  15.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=300, random_state=42;, score=0.880 total time=  17.4s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=100, random_state=42;, score=0.834 total time=   5.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.923 total time=  10.1s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=100, random_state=42;, score=0.962 total time=   4.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.735 total time=  14.1s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=100, random_state=42;, score=0.931 total time=   5.1s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=1000, random_state=42;, score=0.875 total time=  48.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=300, random_state=42;, score=0.733 total time=  15.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=500, random_state=42;, score=0.901 total time=  27.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=1000, random_state=42;, score=0.893 total time=  51.3s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=100, random_state=42;, score=0.987 total time=   4.5s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=500, random_state=42;, score=0.968 total time=  27.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=500, random_state=42;, score=0.987 total time=  25.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=1000, random_state=42;, score=0.867 total time=  52.5s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=100, random_state=42;, score=0.834 total time=   5.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.952 total time=  13.4s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=100, random_state=42;, score=0.962 total time=   4.6s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=50, random_state=42;, score=0.897 total time=   2.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=300, random_state=42;, score=0.937 total time=  16.0s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=50, random_state=42;, score=0.896 total time=   2.6s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=50, random_state=42;, score=0.829 total time=   2.4s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=50, random_state=42;, score=0.899 total time=   3.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, random_state=42;, score=0.897 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.938 total time=  10.4s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=500, random_state=42;, score=0.849 total time=  20.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, random_state=42;, score=0.896 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, random_state=42;, score=0.829 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, random_state=42;, score=0.899 total time=   0.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.897 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.896 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=500, random_state=42;, score=0.735 total time=  24.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.829 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=500, random_state=42;, score=0.842 total time=  23.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.899 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.884 total time=   8.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.977 total time=  15.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=200, random_state=42;, score=0.899 total time=  12.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.733 total time=  12.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=1000, random_state=42;, score=0.926 total time=  52.3s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=1000, random_state=42;, score=0.900 total time=  46.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.987 total time=  15.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=1000, random_state=42;, score=0.962 total time=  48.0s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=500, random_state=42;, score=0.962 total time=  23.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=500, random_state=42;, score=0.952 total time=  25.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=200, random_state=42;, score=0.920 total time=  12.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=1000, random_state=42;, score=0.893 total time=  49.7s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=500, random_state=42;, score=0.688 total time=  29.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.954 total time=  11.1s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=100, random_state=42;, score=0.897 total time=   3.9s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=100, random_state=42;, score=0.896 total time=   4.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.974 total time=  10.6s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.856 total time=  14.6s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.897 total time=   9.9s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=100, random_state=42;, score=0.829 total time=   4.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=200, random_state=42;, score=0.741 total time=  13.0s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.896 total time=   7.8s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=100, random_state=42;, score=0.899 total time=   6.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.969 total time=  11.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=200, random_state=42;, score=0.933 total time=   8.8s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=10, random_state=42;, score=0.897 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=10, random_state=42;, score=0.938 total time=   0.5s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=10, random_state=42;, score=0.887 total time=   0.4s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.975 total time=  14.1s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=10, random_state=42;, score=0.899 total time=   0.6s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.935 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.937 total time=   0.4s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.934 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=500, random_state=42;, score=0.853 total time=  23.3s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.961 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.897 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.722 total time=   3.4s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.896 total time=   0.4s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.829 total time=   0.6s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.849 total time=   9.5s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.899 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.968 total time=   3.0s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.849 total time=   1.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.876 total time=  12.8s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.688 total time=   2.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=300, random_state=42;, score=0.872 total time=  17.1s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.899 total time=  12.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.8s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=300, random_state=42;, score=0.891 total time=  14.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=1000, random_state=42;, score=0.854 total time=  46.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.977 total time=  10.5s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=1000, random_state=42;, score=0.719 total time=  52.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=1000, random_state=42;, score=0.741 total time=  48.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=300, random_state=42;, score=0.923 total time=  14.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=1000, random_state=42;, score=0.888 total time=  59.0s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=500, random_state=42;, score=0.899 total time=  25.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.985 total time=   8.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.938 total time=  11.0s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=300, random_state=42;, score=0.901 total time=  13.0s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=500, random_state=42;, score=0.944 total time=  22.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.965 total time=  10.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.884 total time=  10.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=300, random_state=42;, score=0.739 total time=  15.5s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=300, random_state=42;, score=0.722 total time=  14.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.857 total time=   8.9s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=500, random_state=42;, score=0.576 total time=  23.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.733 total time=  10.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=300, random_state=42;, score=0.896 total time=  15.5s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.975 total time=   9.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=500, random_state=42;, score=0.987 total time=  27.3s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=300, random_state=42;, score=0.964 total time=  13.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.954 total time=  11.7s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=1000, random_state=42;, score=0.804 total time=  46.3s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=10, random_state=42;, score=0.945 total time=   0.8s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=10, random_state=42;, score=0.965 total time=   0.5s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=10, random_state=42;, score=0.874 total time=   0.6s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=300, random_state=42;, score=0.860 total time=  13.2s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=10, random_state=42;, score=0.961 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=200, random_state=42;, score=0.899 total time=  10.4s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.977 total time=  14.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.920 total time=  11.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=1000, random_state=42;, score=0.924 total time=  55.6s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=500, random_state=42;, score=0.805 total time=  25.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=1000, random_state=42;, score=0.895 total time=  53.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=1000, random_state=42;, score=0.739 total time=  52.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=200, random_state=42;, score=0.920 total time=   7.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.884 total time=   7.5s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.987 total time=  10.8s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=300, random_state=42;, score=0.899 total time=  11.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=500, random_state=42;, score=0.842 total time=  22.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=200, random_state=42;, score=0.741 total time=   7.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.735 total time=   7.6s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.856 total time=  10.6s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=300, random_state=42;, score=0.716 total time=  10.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=200, random_state=42;, score=0.933 total time=   7.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.923 total time=   7.6s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=500, random_state=42;, score=0.962 total time=  17.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.975 total time=  10.5s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=300, random_state=42;, score=0.926 total time=  10.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=1000, random_state=42;, score=0.952 total time=  37.5s
# gen	nevals	avg     	min     	max     	std
# 0  	40    	0.886798	0.783213	0.969288	0.0439069
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.9s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=10, random_state=42;, score=0.897 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.8s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=10, random_state=42;, score=0.938 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=10, random_state=42;, score=0.887 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.6s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=10, random_state=42;, score=0.899 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.938 total time=  10.4s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.985 total time=  10.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.974 total time=  11.6s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.897 total time=   9.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=300, random_state=42;, score=0.915 total time=  14.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.977 total time=  15.0s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=300, random_state=42;, score=0.860 total time=  14.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.931 total time=  15.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.931 total time=  16.1s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.965 total time=   9.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.884 total time=  11.1s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.896 total time=  10.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.969 total time=  11.2s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=300, random_state=42;, score=0.899 total time=  12.4s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.987 total time=  12.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=300, random_state=42;, score=0.880 total time=  13.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.857 total time=   9.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.733 total time=   8.6s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.849 total time=   8.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.909 total time=  13.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.909 total time=  16.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.876 total time=  10.0s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.975 total time=   9.5s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=300, random_state=42;, score=0.716 total time=  12.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.954 total time=  10.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.977 total time=   8.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.899 total time=  11.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=300, random_state=42;, score=0.733 total time=  14.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.856 total time=  15.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.735 total time=  13.3s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=100, random_state=42;, score=0.984 total time=   5.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.735 total time=  14.3s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.897 total time=   9.2s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.985 total time=   7.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=100, random_state=42;, score=0.965 total time=   5.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=1000, random_state=42;, score=0.893 total time=  52.3s
# [CV] END algorithm=SAMME, learning_rate=0.7, n_estimators=300, random_state=42;, score=0.926 total time=  15.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=300, random_state=42;, score=0.937 total time=  13.5s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.896 total time=   8.1s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.975 total time=  14.1s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=100, random_state=42;, score=0.905 total time=   5.4s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.966 total time=   1.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.952 total time=  15.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.952 total time=  14.2s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.965 total time=   9.6s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.988 total time=   3.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=100, random_state=42;, score=0.838 total time=   5.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=100, random_state=42;, score=0.975 total time=   5.1s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.849 total time=   7.1s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.895 total time=   7.8s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.754 total time=   1.9s
# [CV] END algorithm=SAMME, learning_rate=1.0, n_estimators=50, random_state=42;, score=0.964 total time=   1.9s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=500, random_state=42;, score=0.838 total time=  23.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=100, random_state=42;, score=0.957 total time=   3.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.857 total time=   7.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=100, random_state=42;, score=0.740 total time=   3.9s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.899 total time=   7.5s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.969 total time=   7.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=100, random_state=42;, score=0.897 total time=   3.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.975 total time=   7.1s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.729 total time=   7.0s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=500, random_state=42;, score=0.901 total time=  17.1s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.962 total time=   7.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=1000, random_state=42;, score=0.962 total time=  40.8s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=500, random_state=42;, score=0.714 total time=  16.9s
# [CV] END algorithm=SAMME, learning_rate=0.5, n_estimators=500, random_state=42;, score=0.806 total time=  17.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=1000, random_state=42;, score=0.854 total time=  36.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=1000, random_state=42;, score=0.924 total time=  36.7s
# 1  	20    	0.912755	0.814925	0.969288	0.0386735
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.964 total time=   0.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.938 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.761 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.937 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, random_state=42;, score=0.897 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, random_state=42;, score=0.896 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, random_state=42;, score=0.829 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, random_state=42;, score=0.899 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=100, random_state=42;, score=0.838 total time=   6.5s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.897 total time=   7.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.985 total time=   7.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.985 total time=  11.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=100, random_state=42;, score=0.957 total time=   5.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.974 total time=   9.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.938 total time=   9.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.974 total time=  10.2s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.977 total time=  13.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.974 total time=  10.6s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.896 total time=   8.5s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.965 total time=   9.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=100, random_state=42;, score=0.740 total time=   6.1s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.965 total time=  10.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.969 total time=   8.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.884 total time=   9.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=500, random_state=42;, score=0.965 total time=  22.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.969 total time=  11.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=100, random_state=42;, score=0.897 total time=   5.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.987 total time=  12.5s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.849 total time=  10.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.969 total time=  11.5s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.857 total time=  10.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.876 total time=   8.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.857 total time=  11.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.733 total time=  10.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.985 total time=   9.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.876 total time=  12.2s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.899 total time=   8.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.876 total time=   9.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.964 total time=   0.5s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.975 total time=   8.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.938 total time=   0.5s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.897 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.761 total time=   0.6s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.896 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.937 total time=   0.5s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.829 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.899 total time=   0.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.856 total time=  14.0s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.975 total time=   8.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.954 total time=  10.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.965 total time=  11.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=100, random_state=42;, score=0.938 total time=   6.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.977 total time=  12.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.977 total time=  11.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=100, random_state=42;, score=0.982 total time=   5.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.977 total time=  10.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=500, random_state=42;, score=0.968 total time=  24.6s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=100, random_state=42;, score=0.984 total time=   5.1s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=100, random_state=42;, score=0.929 total time=   6.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=100, random_state=42;, score=0.965 total time=   4.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.931 total time=  12.6s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.857 total time=   9.0s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.975 total time=  13.5s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=100, random_state=42;, score=0.965 total time=   4.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.920 total time=  10.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=100, random_state=42;, score=0.735 total time=   4.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=100, random_state=42;, score=0.872 total time=   4.6s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.977 total time=  13.5s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=100, random_state=42;, score=0.905 total time=   4.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=100, random_state=42;, score=0.996 total time=   3.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=100, random_state=42;, score=0.851 total time=   4.0s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.975 total time=   6.9s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=100, random_state=42;, score=0.975 total time=   3.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.884 total time=   8.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.909 total time=  11.6s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.987 total time=  10.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=500, random_state=42;, score=0.852 total time=  21.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.735 total time=   7.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.735 total time=  11.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.923 total time=   7.6s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.856 total time=  10.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.952 total time=  11.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=500, random_state=42;, score=0.962 total time=  18.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.975 total time=  10.4s
# 2  	24    	0.929906	0.857899	0.969288	0.0358424
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.6s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.897 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.5s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.896 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.897 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.829 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.896 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.899 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.8s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.829 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.899 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.5s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=100, random_state=42;, score=0.897 total time=   4.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.974 total time=   9.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50, random_state=42;, score=0.966 total time=   2.9s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=100, random_state=42;, score=0.896 total time=   4.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.938 total time=   9.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50, random_state=42;, score=0.875 total time=   1.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.938 total time=   9.3s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.977 total time=  12.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.938 total time=  10.7s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=100, random_state=42;, score=0.722 total time=   4.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50, random_state=42;, score=0.849 total time=   2.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.920 total time=   8.8s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=100, random_state=42;, score=0.829 total time=   4.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50, random_state=42;, score=0.852 total time=   2.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, random_state=42;, score=0.897 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=200, random_state=42;, score=0.969 total time=   9.5s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=100, random_state=42;, score=0.869 total time=   5.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.938 total time=  10.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, random_state=42;, score=0.896 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, random_state=42;, score=0.829 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.884 total time=   8.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=10, random_state=42;, score=0.899 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.884 total time=   8.8s
# [CV] END algorithm=SAMME, learning_rate=0.01, n_estimators=100, random_state=42;, score=0.899 total time=   5.1s
# [CV] END algorithm=SAMME.R, learning_rate=1.0, n_estimators=100, random_state=42;, score=0.849 total time=   4.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=200, random_state=42;, score=0.884 total time=   9.3s
# ...
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.899 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=50, random_state=42;, score=0.915 total time=   2.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.01, n_estimators=50, random_state=42;, score=0.899 total time=   2.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.931 total time=  11.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.909 total time=  10.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.735 total time=  10.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=300, random_state=42;, score=0.952 total time=  11.0s
# 29 	32    	0.961888	0.880367	0.969288	0.0227391
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=10, random_state=42;, score=0.413 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.964 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=10, random_state=42;, score=0.857 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.938 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=10, random_state=42;, score=0.753 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.761 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.5, n_estimators=10, random_state=42;, score=0.918 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.937 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50, random_state=42;, score=0.966 total time=   2.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.964 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.964 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.938 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.938 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.8s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.761 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50, random_state=42;, score=0.875 total time=   2.0s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.761 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.937 total time=   0.7s
# [CV] END algorithm=SAMME.R, learning_rate=0.7, n_estimators=10, random_state=42;, score=0.937 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.982 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.933 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50, random_state=42;, score=0.849 total time=   2.2s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.6s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=10, random_state=42;, score=0.996 total time=   0.5s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=50, random_state=42;, score=0.852 total time=   1.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.938 total time=   7.9s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.884 total time=   7.3s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.733 total time=   7.4s
# [CV] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=200, random_state=42;, score=0.954 total time=   7.4s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=1000, random_state=42;, score=0.909 total time=  34.0s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=1000, random_state=42;, score=0.985 total time=  33.2s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=1000, random_state=42;, score=0.744 total time=  33.6s
# [CV] END algorithm=SAMME, learning_rate=0.1, n_estimators=1000, random_state=42;, score=0.962 total time=  34.1s
# 30 	25    	0.952124	0.73517 	0.969288	0.0440585
# Best individual is: {'n_estimators': 10, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'random_state': 42}
# with fitness: 0.9692884859163934

# %%
# Remove bool values from dict
cv.cv_results_.pop('nan_test_score?')

print("Saving CV results")
file_name = "{}_hpo_best_cv.csv".format(prefix)
# with open(os.path.join(model_dir,file_name), 'w') as cvfile:
#     json.dump(cv.cv_results_, cvfile)
cv_test_scores = pd.DataFrame(cv.cv_results_)
cv_test_scores.to_csv(os.path.join(model_dir,file_name), index=False)
print("{} best params: {}".format(prefix, cv.best_params_))
param_name = "{}_hpo_best_param.json".format(prefix)
with open(os.path.join(model_dir,param_name), 'w') as cvfile:
    json.dump(cv.best_params_, cvfile)
print("{} best score: {}".format(prefix, cv.best_score_))
print("Saving best {} estimator".format(prefix))
model_name = "{}_hpo_best.joblib".format(prefix)
dump(cv.best_estimator_, os.path.join(model_dir,model_name))
# Out:
# Saving CV results
# Phase1_ADA_EV best params: {'n_estimators': 10, 'learning_rate': 0.1, 'algorithm': 'SAMME.R', 'random_state': 42}
# Phase1_ADA_EV best score: 0.9692884859163934
# Saving best Phase1_ADA_EV estimator
# ['/home/gabriel/Research/Aspide/workspace/data_phase/models/Phase1_ADA_EV_hpo_best.joblib']

# %%
y_pred = cv.best_estimator_.predict(X)
custom_scoring_reporting(y_pred, y, definitions, prefix)
# Out:
# Accuracy score is: 0.9827777777777778
# Ballanced accuracy score is: 0.7741464251141595
# Jaccard score (micro): 0.9661387220098306
# Jaccard score (macro): 0.6939049796229403
# Jaccard score (weighted): 0.9704718725301875
# Full classification report
#                     precision    recall  f1-score   support
#
#                  0       1.00      1.00      1.00      4792
# target_ddot_master       0.96      0.93      0.94        91
#  target_mem_master       0.65      0.97      0.78       132
#  target_cpu_master       0.00      0.00      0.00        64
# target_copy_master       0.97      0.97      0.97       321
#
#           accuracy                           0.98      5400
#          macro avg       0.71      0.77      0.74      5400
#       weighted avg       0.98      0.98      0.98      5400
#
# Imbalanced Classification report
#                           pre       rec       spe        f1       geo       iba       sup
#
#                  0       1.00      1.00      0.98      1.00      0.99      0.98      4792
# target_ddot_master       0.96      0.93      1.00      0.94      0.97      0.93        91
#  target_mem_master       0.65      0.97      0.99      0.78      0.98      0.96       132
#  target_cpu_master       0.00      0.00      1.00      0.00      0.00      0.00        64
# target_copy_master       0.97      0.97      1.00      0.97      0.98      0.96       321
#
#        avg / total       0.98      0.98      0.98      0.98      0.98      0.97      5400
# /home/gabriel/anaconda3/envs/pyaspide/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/gabriel/anaconda3/envs/pyaspide/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/gabriel/anaconda3/envs/pyaspide/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/gabriel/anaconda3/envs/pyaspide/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/gabriel/anaconda3/envs/pyaspide/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/gabriel/anaconda3/envs/pyaspide/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/gabriel/anaconda3/envs/pyaspide/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/gabriel/anaconda3/envs/pyaspide/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Confusion matrix")
cf_matrix = confusion_matrix(y, y_pred)
plt.figure(dpi=600)
sns_cf = sns.heatmap(cf_matrix, annot=True, yticklabels=list(definitions), xticklabels=list(definitions))
cf_fig = "{}_cf.png".format(prefix)
sns_cf.figure.savefig(os.path.join(model_dir, cf_fig), format='pdf',
           bbox_inches='tight', pad_inches=0)

# Extract Feature importance
feat_importances = pd.Series(cv.best_estimator_.feature_importances_, index=list(data.drop('target', axis=1).columns))
featureimp_name = "{}_hpo_best_featureimp.csv".format(prefix)
feat_importances.to_csv(os.path.join(model_dir, featureimp_name), index=True)
# print(feat_importances.head(10))
sorted_feature = feat_importances.sort_values(ascending=True)
# Plot the feature importances of the forest
# plt.figure()
plt.figure(figsize=(10,20), dpi=600)
plt.title("Feature importances")
plt.barh(range(X.shape[1]), sorted_feature,
       color="r", align="center", )
# If you want to define your own labels,
# change indices to a list of labels on the following line.
plt.yticks(range(X.shape[1]), sorted_feature.index)
plt.ylim([-1, X.shape[1]])
plt.show()
# Out:
# Confusion matrix
# /home/gabriel/anaconda3/envs/pyaspide/lib/python3.6/site-packages/ipykernel_launcher.py:11: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# Scoring on holdout or other dataset

# %%
#Creating the dependent variable class
# factor_h = pd.factorize(df_clean['target'])
# df_clean.target = factor_h[0]
# definitions_h = factor_h[1]

# %%
# print("Splitting dataset into data and ground truth ...")
# X_h = df_clean.drop('target', axis=1)
# y_h = df_clean['target']

# Scale
# X_h

# %%
# X_h = scaler.transform(X_h)

# %%
# y_pred_h = cv.best_estimator_.predict(X_h)
#
# custom_scoring_reporting(y_pred_h, y_h, definitions, prefix="rf_holdout")

# %%
# y_pred = cv.best_estimator_.predict(X)
# custom_scoring_reporting(y_pred, y, definitions, prefix)

# jaccard_score(y_h, y_pred_h, average='micro')
# y_pred_h
