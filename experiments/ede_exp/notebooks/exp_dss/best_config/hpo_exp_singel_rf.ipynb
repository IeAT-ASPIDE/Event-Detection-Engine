# %%
"""
Random forest Experiments Serrano/AUDSOME Phase 1
Gabriel Iuhasz
Anomaly Only
Audsome
"""
import numpy as np
np.random.seed(42)
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import balanced_accuracy_score, make_scorer, classification_report, accuracy_score, jaccard_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

import xgboost as xgb
# from sklearn.externals import joblib
from joblib import dump, load
import json
import os
import matplotlib.pyplot as plt
import seaborn as sns
from evolutionary_search import EvolutionaryAlgorithmSearchCV
from subprocess import check_output
# %matplotlib inline

# %%
def custom_scoring_reporting(y_pred,
                             y,
                             definitions,
                             prefix):
    """
    Custom function for handling scoring and reporting
    :param y_pred: model predictions
    :param y: ground truth
    :param definitions: variable class definitions (factorize)
    :param prefix: prefix to saved files and images
    :return: 0
    """
    print("Accuracy score is: {}".format(accuracy_score(y, y_pred)))
    print("Ballanced accuracy score is: {}".format(balanced_accuracy_score(y, y_pred)))
    print("Jaccard score (micro): {}".format(jaccard_score(y, y_pred, average='micro')))
    print("Jaccard score (macro): {}".format(jaccard_score(y, y_pred, average='macro')))
    print("Jaccard score (weighted): {}".format(jaccard_score(y, y_pred, average='weighted')))


    print("Full classification report")
    print(classification_report(y, y_pred, target_names=definitions))
    report = classification_report(y, y_pred, output_dict=True)
    df_classification_report = pd.DataFrame(report).transpose()
    classification_rep_name = "{}_classification_rep_best.csv".format(prefix)
    df_classification_report.to_csv(os.path.join(model_dir,classification_rep_name), index=False)


    print("Imbalanced Classification report")
    print(classification_report_imbalanced(y, y_pred, target_names=definitions))
    imb_report = classification_report_imbalanced(y, y_pred, target_names=definitions, output_dict=True)
    df_imb_classification_report = pd.DataFrame(imb_report).transpose()
    classification_imb_rep_name = "{}_imb_classification_rep_best.csv".format(prefix)
    df_imb_classification_report.to_csv(os.path.join(model_dir,classification_imb_rep_name), index=False)

# %% [markdown]
# Common preprocessing for all experiments

# %%
print("Checking files in data location ...")
# train_dir = '/Users/Gabriel/Dropbox/Research/ASPIDE/Datasets/ECI Chaos/Distributed Phase 1/finalized/single_node/training'
# train_dir = '/home/gabriel/Research/Aspide/workspace/data_phase'
train_dir = '/home/gabriel/research/dipet/serrano/data'
print(check_output(["ls", train_dir]).decode("utf8"))
# Out:
# Checking files in data location ...
# df_anomaly.csv
# df_audsome.csv
# df_clean_ausdome_single.csv
# df_clean_single.csv
# models

# %%
print("Setting paths and datasets")
# Checking if directory exists for data, modells and processed

# data_dir = os.path.join(train_dir,'data')
model_dir = os.path.join(train_dir,'models')
# processed_dir = os.path.join(train_dir,'processed')
# if not os.path.exists(data_dir):
#     os.makedirs(data_dir)
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
# if not os.path.exists(processed_dir):
#     os.makedirs(processed_dir)
# Out:
# Setting paths and datasets

# %%
df_anomaly = pd.read_csv(os.path.join(train_dir,"df_anomaly.csv"))
df_audsome = pd.read_csv(os.path.join(train_dir,"df_audsome.csv"))
df_clean = pd.read_csv(os.path.join(train_dir,"df_clean_single.csv"))
df_clean_audsome = pd.read_csv(os.path.join(train_dir,"df_clean_ausdome_single.csv"))

# Set index as time
df_anomaly.set_index('time', inplace=True)
df_audsome.set_index('time', inplace=True)
df_clean.set_index('time', inplace=True)
df_clean_audsome.set_index('time', inplace=True)

# %%
print("Dataset chosen ...")
data = df_anomaly

# Nice print
nice_y = data['target']
data.shape
# Out:
# Dataset chosen ...
# (5400, 90)

# %%
# Uncomment for removing dummy TODO CHECK if adding back dummy
# data.loc[data.target == "dummy", 'target'] = "0"

#Creating the dependent variable class
factor = pd.factorize(data['target'])
data.target = factor[0]
definitions = factor[1]
# print(data.target.head())
# print(definitions)

# %%
print("Splitting dataset into training and ground truth ...")
X = data.drop('target', axis=1)
y = data['target']
# Out:
# Splitting dataset into training and ground truth ...

# %%
# Plot class distribution
print("Ploting class distribution ..")
pltdist= sns.countplot(nice_y)
pltdist.set_xticklabels(pltdist.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# Ploting class distribution ..
# /home/gabriel/anaconda3/envs/dipet_2/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print("Scaling dataset")
# scaler = StandardScaler()
# scaler = RobustScaler()
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(X_scaled, index=X.index, columns=X.columns) # transform back to df
# Out:
# Scaling dataset

# %% [markdown]
# Starting of experiment for RandomForest only

# %%
# Name of experiment
# RandomForest
prefix = 'Phase1_RF_evs'
paramgrid = {
    "n_estimators": [10, 50, 100, 200, 300, 500, 1000],
    "max_depth": [5, 10, 25, 50, None],
    "max_features": [5, 10, 20, 30, 50, 60, 85, 'auto'],
    "min_samples_split":[2, 5, 11],
    "min_samples_leaf":[1, 5, 11],
    "criterion": ['entropy', 'gini'],
    "random_state": [42]
}
model = RandomForestClassifier()

# %%
#Example of HPO methods https://github.com/LiYangHart/Hyperparameter-Optimization-of-Machine-Learning-Algorithms/blob/master/HPO_Classification.ipynb
# scorer = make_scorer(accuracy_score, )
scorer = make_scorer(jaccard_score, average="micro") # TODO check average
# scorer = 'accuracy'
n_splits = 4 # default 4

cv_type = StratifiedKFold(n_splits=n_splits)
nj = 40 # Number of jobs

cv = EvolutionaryAlgorithmSearchCV(estimator=model,
                                   params=paramgrid,
                                   scoring=scorer,
                                   cv=cv_type, # StratifiedKFold not supported for multilabel-indicator (oh encoding)
                                   verbose=4,
                                   population_size=40, # 40
                                   gene_mutation_prob=0.20,
                                   gene_crossover_prob=0.5,
                                   tournament_size=4,
                                   generations_number=30, #10
                                   n_jobs=nj) # for dnn n_jobs must be set to 1 rest is 8

# %%
cv.fit(X, y)
# Out:
# Types [1, 1, 1, 1, 1, 1, 1] and maxint [6, 4, 7, 2, 2, 1, 0] detected
# --- Evolve in 5040 possible combinations ---
# [CV] END criterion=gini, max_depth=25, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=10, random_state=42;, score=0.929 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=10, random_state=42;, score=0.988 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=10, random_state=42;, score=0.951 total time=   0.1s[CV] END criterion=entropy, max_depth=50, max_features=5, min_samples_leaf=11, min_samples_split=11, n_estimators=50, random_state=42;, score=0.937 total time=   0.3s[CV] END criterion=entropy, max_depth=10, max_features=30, min_samples_leaf=1, min_samples_split=2, n_estimators=10, random_state=42;, score=0.966 total time=   0.3s
#
#
# [CV] END criterion=entropy, max_depth=50, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=50, random_state=42;, score=0.972 total time=   0.5s[CV] END criterion=gini, max_depth=10, max_features=85, min_samples_leaf=5, min_samples_split=11, n_estimators=10, random_state=42;, score=0.966 total time=   0.4s[CV] END criterion=gini, max_depth=25, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=10, random_state=42;, score=0.981 total time=   0.1s
#
# [CV] END criterion=entropy, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.985 total time=   0.4s
#
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=100, random_state=42;, score=0.955 total time=   0.7s[CV] END criterion=entropy, max_depth=50, max_features=5, min_samples_leaf=11, min_samples_split=11, n_estimators=50, random_state=42;, score=0.966 total time=   0.3s[CV] END criterion=gini, max_depth=25, max_features=5, min_samples_leaf=5, min_samples_split=11, n_estimators=10, random_state=42;, score=0.916 total time=   0.1s[CV] END criterion=entropy, max_depth=10, max_features=30, min_samples_leaf=1, min_samples_split=2, n_estimators=10, random_state=42;, score=0.978 total time=   0.4s
#
#
#
# [CV] END criterion=gini, max_depth=10, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.985 total time=   1.0s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.985 total time=   0.4s
# [CV] END criterion=gini, max_depth=25, max_features=5, min_samples_leaf=5, min_samples_split=11, n_estimators=10, random_state=42;, score=0.966 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=5, min_samples_leaf=5, min_samples_split=11, n_estimators=10, random_state=42;, score=0.888 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=5, min_samples_leaf=5, min_samples_split=11, n_estimators=10, random_state=42;, score=0.930 total time=   0.1s
# [CV] END criterion=entropy, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.987 total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, max_features=30, min_samples_leaf=1, min_samples_split=2, n_estimators=10, random_state=42;, score=0.823 total time=   0.2s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=50, random_state=42;, score=0.988 total time=   0.6s[CV] END criterion=gini, max_depth=10, max_features=85, min_samples_leaf=5, min_samples_split=11, n_estimators=10, random_state=42;, score=0.991 total time=   0.5s
#
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=200, random_state=42;, score=0.985 total time=   1.2s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=5, min_samples_leaf=11, min_samples_split=11, n_estimators=50, random_state=42;, score=0.942 total time=   0.3s
# [CV] END criterion=entropy, max_depth=50, max_features=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42;, score=0.940 total time=   1.0s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
# [CV] END criterion=entropy, max_depth=None, max_features=60, min_samples_leaf=11, min_samples_split=11, n_estimators=10, random_state=42;, score=0.985 total time=   0.4s
# [CV] END criterion=gini, max_depth=50, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.985 total time=   1.3s
# [CV] END criterion=entropy, max_depth=10, max_features=30, min_samples_leaf=1, min_samples_split=2, n_estimators=10, random_state=42;, score=0.903 total time=   0.3s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.987 total time=   0.5s
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=100, random_state=42;, score=0.987 total time=   0.6s[CV] END criterion=gini, max_depth=10, max_features=85, min_samples_leaf=5, min_samples_split=11, n_estimators=10, random_state=42;, score=0.915 total time=   0.3s
#
# [CV] END criterion=entropy, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.947 total time=   0.4s
# [CV] END criterion=entropy, max_depth=50, max_features=5, min_samples_leaf=11, min_samples_split=11, n_estimators=50, random_state=42;, score=0.978 total time=   0.3s
# [CV] END criterion=entropy, max_depth=50, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=50, random_state=42;, score=0.947 total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42;, score=0.940 total time=   1.8s
# [CV] END criterion=entropy, max_depth=None, max_features=60, min_samples_leaf=11, min_samples_split=11, n_estimators=10, random_state=42;, score=0.988 total time=   0.4s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.947 total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=85, min_samples_leaf=5, min_samples_split=11, n_estimators=10, random_state=42;, score=0.974 total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.987 total time=   0.9s
# [CV] END criterion=entropy, max_depth=None, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.994 total time=   0.4s
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=100, random_state=42;, score=0.947 total time=   0.6s
# [CV] END criterion=entropy, max_depth=50, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=50, random_state=42;, score=0.996 total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=60, min_samples_leaf=11, min_samples_split=11, n_estimators=10, random_state=42;, score=0.912 total time=   0.4s
# [CV] END criterion=entropy, max_depth=10, max_features=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42;, score=0.942 total time=   2.2s
# [CV] END criterion=entropy, max_depth=50, max_features=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42;, score=0.979 total time=   0.9s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.994 total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=11, n_estimators=300, random_state=42;, score=0.935 total time=   1.9s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=200, random_state=42;, score=0.987 total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=60, min_samples_leaf=11, min_samples_split=11, n_estimators=10, random_state=42;, score=0.975 total time=   0.4s
# [CV] END criterion=gini, max_depth=None, max_features=auto, min_samples_leaf=11, min_samples_split=2, n_estimators=100, random_state=42;, score=0.994 total time=   0.6s
# [CV] END criterion=gini, max_depth=5, max_features=85, min_samples_leaf=1, min_samples_split=5, n_estimators=50, random_state=42;, score=0.964 total time=   2.3s
# [CV] END criterion=gini, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42;, score=0.965 total time=   2.8s[CV] END criterion=gini, max_depth=10, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.945 total time=   0.9s
#
# [CV] END criterion=gini, max_depth=50, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.987 total time=   1.4s
# [CV] END criterion=entropy, max_depth=25, max_features=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500, random_state=42;, score=0.924 total time=   3.0s
# [CV] END criterion=entropy, max_depth=50, max_features=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42;, score=0.843 total time=   0.9s
# [CV] END criterion=gini, max_depth=25, max_features=50, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.985 total time=   2.3s
# [CV] END criterion=gini, max_depth=50, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=100, random_state=42;, score=0.985 total time=   2.6s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=200, random_state=42;, score=0.945 total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42;, score=0.985 total time=   1.6s
# [CV] END criterion=gini, max_depth=10, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.996 total time=   0.9s
# [CV] END criterion=gini, max_depth=50, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.940 total time=   1.1s
# [CV] END criterion=entropy, max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=11, n_estimators=300, random_state=42;, score=0.988 total time=   1.6s
# [CV] END criterion=entropy, max_depth=50, max_features=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42;, score=0.962 total time=   0.9s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=500, random_state=42;, score=0.959 total time=   4.0s
# [CV] END criterion=entropy, max_depth=10, max_features=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42;, score=0.979 total time=   2.1s
# [CV] END criterion=gini, max_depth=None, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=500, random_state=42;, score=0.985 total time=   4.5s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=11, min_samples_split=2, n_estimators=200, random_state=42;, score=0.996 total time=   1.1s
# [CV] END criterion=gini, max_depth=5, max_features=85, min_samples_leaf=1, min_samples_split=5, n_estimators=50, random_state=42;, score=0.947 total time=   2.2s
# [CV] END criterion=entropy, max_depth=5, max_features=10, min_samples_leaf=1, min_samples_split=11, n_estimators=500, random_state=42;, score=0.958 total time=   4.4s
# [CV] END criterion=entropy, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42;, score=0.840 total time=   1.6s
# [CV] END criterion=gini, max_depth=50, max_features=50, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42;, score=0.972 total time=   5.2s
# [CV] END criterion=gini, max_depth=50, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.996 total time=   1.4s
# [CV] END criterion=gini, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42;, score=0.979 total time=   2.6s
# [CV] END criterion=gini, max_depth=25, max_features=50, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.987 total time=   2.4s
# [CV] END criterion=entropy, max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=11, n_estimators=300, random_state=42;, score=0.931 total time=   1.6s
# [CV] END criterion=entropy, max_depth=25, max_features=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500, random_state=42;, score=0.978 total time=   2.8s
# [CV] END criterion=gini, max_depth=50, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=100, random_state=42;, score=0.985 total time=   2.6s
# [CV] END criterion=entropy, max_depth=10, max_features=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42;, score=0.824 total time=   1.9s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.962 total time=   5.8s
# [CV] END criterion=gini, max_depth=5, max_features=85, min_samples_leaf=1, min_samples_split=5, n_estimators=50, random_state=42;, score=0.847 total time=   1.7s
# [CV] END criterion=entropy, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42;, score=0.962 total time=   1.7s[CV] END criterion=gini, max_depth=25, max_features=85, min_samples_leaf=11, min_samples_split=11, n_estimators=200, random_state=42;, score=0.966 total time=   6.5s
#
# [CV] END criterion=gini, max_depth=25, max_features=50, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.931 total time=   1.6s
# [CV] END criterion=entropy, max_depth=5, max_features=5, min_samples_leaf=1, min_samples_split=11, n_estimators=300, random_state=42;, score=0.961 total time=   1.7s
# [CV] END criterion=gini, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42;, score=0.872 total time=   2.0s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=11, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.987 total time=   7.8s
# [CV] END criterion=gini, max_depth=50, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=300, random_state=42;, score=0.985 total time=   7.5s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=500, random_state=42;, score=0.988 total time=   3.7s
# [CV] END criterion=entropy, max_depth=5, max_features=60, min_samples_leaf=11, min_samples_split=5, n_estimators=200, random_state=42;, score=0.987 total time=   7.2s
# [CV] END criterion=gini, max_depth=50, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=100, random_state=42;, score=0.895 total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100, random_state=42;, score=0.957 total time=   2.2s
# [CV] END criterion=entropy, max_depth=25, max_features=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500, random_state=42;, score=0.785 total time=   2.7s
# [CV] END criterion=gini, max_depth=5, max_features=85, min_samples_leaf=1, min_samples_split=5, n_estimators=50, random_state=42;, score=0.909 total time=   2.1s
# [CV] END criterion=gini, max_depth=None, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=500, random_state=42;, score=0.987 total time=   4.2s
# [CV] END criterion=entropy, max_depth=5, max_features=10, min_samples_leaf=1, min_samples_split=11, n_estimators=500, random_state=42;, score=0.987 total time=   4.1s
# [CV] END criterion=gini, max_depth=25, max_features=50, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.996 total time=   2.3s
# [CV] END criterion=entropy, max_depth=25, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=300, random_state=42;, score=0.979 total time=   9.7s
# [CV] END criterion=gini, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=5, n_estimators=100, random_state=42;, score=0.893 total time=   2.6s
# [CV] END criterion=entropy, max_depth=25, max_features=85, min_samples_leaf=5, min_samples_split=5, n_estimators=200, random_state=42;, score=0.984 total time=  10.2s
# [CV] END criterion=gini, max_depth=50, max_features=50, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42;, score=0.985 total time=   5.1s
# [CV] END criterion=gini, max_depth=50, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=100, random_state=42;, score=0.893 total time=   2.6s
# [CV] END criterion=entropy, max_depth=25, max_features=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500, random_state=42;, score=0.957 total time=   2.8s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=500, random_state=42;, score=0.945 total time=   3.7s
# [CV] END criterion=entropy, max_depth=10, max_features=60, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42;, score=0.966 total time=  11.6s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.987 total time=   5.3s
# [CV] END criterion=gini, max_depth=None, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=500, random_state=42;, score=0.945 total time=   3.9s
# [CV] END criterion=entropy, max_depth=5, max_features=10, min_samples_leaf=1, min_samples_split=11, n_estimators=500, random_state=42;, score=0.944 total time=   4.0s
# [CV] END criterion=gini, max_depth=25, max_features=85, min_samples_leaf=11, min_samples_split=11, n_estimators=200, random_state=42;, score=0.990 total time=   6.6s
# [CV] END criterion=gini, max_depth=50, max_features=50, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42;, score=0.875 total time=   4.0s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=11, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.987 total time=   7.1s
# [CV] END criterion=entropy, max_depth=5, max_features=60, min_samples_leaf=11, min_samples_split=5, n_estimators=200, random_state=42;, score=0.988 total time=   6.9s
# [CV] END criterion=gini, max_depth=50, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=300, random_state=42;, score=0.985 total time=   7.4s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=500, random_state=42;, score=0.996 total time=   3.9s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.945 total time=   5.1s
# [CV] END criterion=gini, max_depth=None, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=500, random_state=42;, score=0.996 total time=   4.3s
# [CV] END criterion=entropy, max_depth=5, max_features=10, min_samples_leaf=1, min_samples_split=11, n_estimators=500, random_state=42;, score=0.996 total time=   4.2s
# [CV] END criterion=gini, max_depth=None, max_features=85, min_samples_leaf=5, min_samples_split=11, n_estimators=500, random_state=42;, score=0.971 total time=  17.5s
# [CV] END criterion=gini, max_depth=25, max_features=85, min_samples_leaf=11, min_samples_split=11, n_estimators=200, random_state=42;, score=0.915 total time=   4.3s
# [CV] END criterion=entropy, max_depth=25, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=300, random_state=42;, score=0.988 total time=   9.7s
# [CV] END criterion=gini, max_depth=50, max_features=50, min_samples_leaf=1, min_samples_split=5, n_estimators=200, random_state=42;, score=0.952 total time=   5.2s
# [CV] END criterion=entropy, max_depth=25, max_features=85, min_samples_leaf=5, min_samples_split=5, n_estimators=200, random_state=42;, score=0.990 total time=   9.7s
# [CV] END criterion=entropy, max_depth=5, max_features=60, min_samples_leaf=11, min_samples_split=5, n_estimators=200, random_state=42;, score=0.935 total time=   6.0s
# [CV] END criterion=gini, max_depth=50, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=300, random_state=42;, score=0.871 total time=   6.0s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=11, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.945 total time=   7.2s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.996 total time=   5.4s
# [CV] END criterion=entropy, max_depth=10, max_features=60, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42;, score=0.990 total time=  11.5s
# [CV] END criterion=gini, max_depth=25, max_features=85, min_samples_leaf=11, min_samples_split=11, n_estimators=200, random_state=42;, score=0.996 total time=   6.6s
# [CV] END criterion=gini, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.985 total time=  24.4s
# [CV] END criterion=entropy, max_depth=25, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=300, random_state=42;, score=0.843 total time=   8.3s
# [CV] END criterion=entropy, max_depth=25, max_features=85, min_samples_leaf=5, min_samples_split=5, n_estimators=200, random_state=42;, score=0.915 total time=   8.3s
# [CV] END criterion=entropy, max_depth=5, max_features=60, min_samples_leaf=11, min_samples_split=5, n_estimators=200, random_state=42;, score=0.975 total time=   7.4s
# [CV] END criterion=gini, max_depth=50, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=300, random_state=42;, score=0.952 total time=   7.7s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=11, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.996 total time=   7.6s
# [CV] END criterion=entropy, max_depth=25, max_features=50, min_samples_leaf=1, min_samples_split=2, n_estimators=1000, random_state=42;, score=0.966 total time=  31.5s
# [CV] END criterion=entropy, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.966 total time=  31.3s
# [CV] END criterion=entropy, max_depth=10, max_features=60, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42;, score=0.813 total time=   9.7s
# [CV] END criterion=entropy, max_depth=5, max_features=60, min_samples_leaf=11, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.987 total time=  34.6s
# [CV] END criterion=gini, max_depth=None, max_features=85, min_samples_leaf=5, min_samples_split=11, n_estimators=500, random_state=42;, score=0.990 total time=  18.8s
# [CV] END criterion=entropy, max_depth=25, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=300, random_state=42;, score=0.969 total time=  10.4s
# [CV] END criterion=entropy, max_depth=25, max_features=85, min_samples_leaf=5, min_samples_split=5, n_estimators=200, random_state=42;, score=0.975 total time=  10.7s
# [CV] END criterion=entropy, max_depth=10, max_features=60, min_samples_leaf=1, min_samples_split=2, n_estimators=300, random_state=42;, score=0.959 total time=  12.4s
# [CV] END criterion=gini, max_depth=None, max_features=85, min_samples_leaf=5, min_samples_split=11, n_estimators=500, random_state=42;, score=0.915 total time=  11.4s
# [CV] END criterion=gini, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.985 total time=  24.9s
# [CV] END criterion=entropy, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.988 total time=  32.5s
# [CV] END criterion=entropy, max_depth=25, max_features=50, min_samples_leaf=1, min_samples_split=2, n_estimators=1000, random_state=42;, score=0.990 total time=  32.6s
# [CV] END criterion=gini, max_depth=None, max_features=85, min_samples_leaf=5, min_samples_split=11, n_estimators=500, random_state=42;, score=0.975 total time=  18.2s
# [CV] END criterion=gini, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.896 total time=  19.9s
# [CV] END criterion=entropy, max_depth=5, max_features=60, min_samples_leaf=11, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.990 total time=  34.1s
# [CV] END criterion=entropy, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.861 total time=  27.7s
# [CV] END criterion=entropy, max_depth=25, max_features=50, min_samples_leaf=1, min_samples_split=2, n_estimators=1000, random_state=42;, score=0.821 total time=  27.8s
# [CV] END criterion=gini, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.955 total time=  25.4s
# [CV] END criterion=entropy, max_depth=5, max_features=60, min_samples_leaf=11, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.938 total time=  30.4s
# [CV] END criterion=entropy, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.969 total time=  35.1s
# [CV] END criterion=entropy, max_depth=25, max_features=50, min_samples_leaf=1, min_samples_split=2, n_estimators=1000, random_state=42;, score=0.958 total time=  35.1s
# [CV] END criterion=entropy, max_depth=5, max_features=60, min_samples_leaf=11, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.975 total time=  36.9s
# gen	nevals	avg     	min     	max   	std
# 0  	40    	0.955843	0.910881	0.9793	0.0207452
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=50, random_state=42;, score=0.987 total time=   0.3s
# [CV] END criterion=entropy, max_depth=None, max_features=60, min_samples_leaf=11, min_samples_split=11, n_estimators=10, random_state=42;, score=0.985 total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.958 total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.955 total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=5, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.922 total time=   0.4s
# [CV] END criterion=entropy, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=50, random_state=42;, score=0.940 total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=50, random_state=42;, score=0.987 total time=   0.3s
# [CV] END criterion=gini, max_depth=50, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.958 total time=   0.6s
# [CV] END criterion=entropy, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.987 total time=   0.7s
# [CV] END criterion=entropy, max_depth=50, max_features=85, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.969 total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=60, min_samples_leaf=11, min_samples_split=11, n_estimators=10, random_state=42;, score=0.988 total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.988 total time=   0.3s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.985 total time=   0.8s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=50, random_state=42;, score=0.947 total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=5, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.972 total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.985 total time=   0.9s
# [CV] END criterion=entropy, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=50, random_state=42;, score=0.985 total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.987 total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.944 total time=   0.3s
# [CV] END criterion=entropy, max_depth=None, max_features=60, min_samples_leaf=11, min_samples_split=11, n_estimators=10, random_state=42;, score=0.912 total time=   0.3s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=50, random_state=42;, score=0.996 total time=   0.3s
# [CV] END criterion=gini, max_depth=50, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.988 total time=   0.6s
# [CV] END criterion=entropy, max_depth=50, max_features=85, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.990 total time=   0.5s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42;, score=0.938 total time=   1.1s
# [CV] END criterion=gini, max_depth=10, max_features=5, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.948 total time=   0.4s
# [CV] END criterion=entropy, max_depth=50, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.985 total time=   1.3s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.994 total time=   0.3s
# [CV] END criterion=entropy, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.987 total time=   0.7s
# [CV] END criterion=gini, max_depth=50, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.985 total time=   1.3s
# [CV] END criterion=entropy, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=50, random_state=42;, score=0.923 total time=   0.4s
# [CV] END criterion=entropy, max_depth=None, max_features=60, min_samples_leaf=11, min_samples_split=11, n_estimators=10, random_state=42;, score=0.975 total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.947 total time=   0.5s
# [CV] END criterion=entropy, max_depth=50, max_features=85, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.915 total time=   0.4s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.987 total time=   0.9s[CV] END criterion=gini, max_depth=10, max_features=5, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.962 total time=   0.4s
#
# [CV] END criterion=gini, max_depth=50, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.945 total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.987 total time=   0.9s
# [CV] END criterion=entropy, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=11, n_estimators=50, random_state=42;, score=0.961 total time=   0.4s
# [CV] END criterion=entropy, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.944 total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.994 total time=   0.5s
# [CV] END criterion=entropy, max_depth=50, max_features=85, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.975 total time=   0.5s
# [CV] END criterion=gini, max_depth=50, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.996 total time=   0.6s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42;, score=0.987 total time=   1.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.945 total time=   0.8s
# [CV] END criterion=entropy, max_depth=50, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.987 total time=   1.3s
# [CV] END criterion=gini, max_depth=10, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.945 total time=   0.8s
# [CV] END criterion=gini, max_depth=50, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.987 total time=   1.3s
# [CV] END criterion=entropy, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.996 total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=5, min_samples_leaf=11, min_samples_split=11, n_estimators=500, random_state=42;, score=0.937 total time=   2.6s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.996 total time=   0.9s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42;, score=0.916 total time=   1.1s
# [CV] END criterion=gini, max_depth=10, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.996 total time=   0.9s
# [CV] END criterion=gini, max_depth=50, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.940 total time=   1.1s
# [CV] END criterion=entropy, max_depth=50, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.944 total time=   1.3s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=500, random_state=42;, score=0.964 total time=   3.8s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200, random_state=42;, score=0.988 total time=   1.1s
# [CV] END criterion=gini, max_depth=50, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=100, random_state=42;, score=0.996 total time=   1.3s
# [CV] END criterion=entropy, max_depth=50, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.996 total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, max_features=5, min_samples_leaf=11, min_samples_split=11, n_estimators=500, random_state=42;, score=0.988 total time=   2.5s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.962 total time=   5.3s[CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.962 total time=   5.3s
#
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=11, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.987 total time=   7.3s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=500, random_state=42;, score=0.987 total time=   3.7s
# [CV] END criterion=entropy, max_depth=5, max_features=5, min_samples_leaf=11, min_samples_split=11, n_estimators=500, random_state=42;, score=0.949 total time=   2.5s
# [CV] END criterion=entropy, max_depth=5, max_features=5, min_samples_leaf=11, min_samples_split=11, n_estimators=500, random_state=42;, score=0.987 total time=   2.6s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.987 total time=   5.2s[CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.987 total time=   5.2s
#
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=500, random_state=42;, score=0.945 total time=   3.7s
# [CV] END criterion=gini, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=500, random_state=42;, score=0.985 total time=  12.0s
# [CV] END criterion=gini, max_depth=5, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.985 total time=  12.1s
# [CV] END criterion=entropy, max_depth=None, max_features=20, min_samples_leaf=5, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.987 total time=  12.9s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=11, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.987 total time=   7.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=500, random_state=42;, score=0.996 total time=   3.9s
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.945 total time=   5.1s[CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.945 total time=   5.1s
#
# [CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.996 total time=   5.4s[CV] END criterion=gini, max_depth=5, max_features=10, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.996 total time=   5.4s
#
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=11, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.945 total time=   7.2s
# [CV] END criterion=gini, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=500, random_state=42;, score=0.985 total time=  12.4s
# [CV] END criterion=gini, max_depth=5, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.987 total time=  12.8s
# [CV] END criterion=entropy, max_depth=None, max_features=20, min_samples_leaf=5, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.987 total time=  12.8s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=11, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.996 total time=   7.6s
# [CV] END criterion=gini, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=500, random_state=42;, score=0.880 total time=   9.9s
# [CV] END criterion=gini, max_depth=5, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.940 total time=  10.6s
# [CV] END criterion=entropy, max_depth=None, max_features=20, min_samples_leaf=5, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.942 total time=  12.6s
# [CV] END criterion=gini, max_depth=None, max_features=50, min_samples_leaf=1, min_samples_split=11, n_estimators=500, random_state=42;, score=0.954 total time=  12.7s
# [CV] END criterion=gini, max_depth=5, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=1000, random_state=42;, score=0.996 total time=  13.0s
# [CV] END criterion=entropy, max_depth=None, max_features=20, min_samples_leaf=5, min_samples_split=11, n_estimators=1000, random_state=42;, score=0.996 total time=  14.0s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# 1  	22    	0.970722	0.946216	0.9793	0.00903637
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.988 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.988 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.945 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.945 total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=50, random_state=42;, score=0.987 total time=   0.3s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.996 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.996 total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.985 total time=   0.4s
# [CV] END criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=42;, score=0.959 total time=   0.4s
# [CV] END criterion=gini, max_depth=25, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.961 total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=50, random_state=42;, score=0.987 total time=   0.3s
# [CV] END criterion=gini, max_depth=None, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=42;, score=0.985 total time=   0.9s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.987 total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=50, random_state=42;, score=0.947 total time=   0.3s[CV] END criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=42;, score=0.988 total time=   0.4s
#
# [CV] END criterion=gini, max_depth=None, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.985 total time=   0.8s
# [CV] END criterion=gini, max_depth=10, max_features=50, min_samples_leaf=5, min_samples_split=5, n_estimators=50, random_state=42;, score=0.987 total time=   1.1s
# [CV] END criterion=gini, max_depth=25, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.987 total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=50, random_state=42;, score=0.996 total time=   0.3s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.947 total time=   0.4s
# [CV] END criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=42;, score=0.944 total time=   0.4s
# [CV] END criterion=entropy, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=42;, score=0.987 total time=   1.4s
# [CV] END criterion=gini, max_depth=25, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.947 total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=300, random_state=42;, score=0.962 total time=   1.6s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=11, n_estimators=50, random_state=42;, score=0.994 total time=   0.4s
# [CV] END criterion=gini, max_depth=None, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=42;, score=0.987 total time=   0.9s
# [CV] END criterion=entropy, max_depth=25, max_features=10, min_samples_leaf=5, min_samples_split=2, n_estimators=50, random_state=42;, score=0.996 total time=   0.4s
# [CV] END criterion=gini, max_depth=None, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.987 total time=   0.8s
# [CV] END criterion=gini, max_depth=25, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.996 total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=50, min_samples_leaf=5, min_samples_split=5, n_estimators=50, random_state=42;, score=0.987 total time=   1.2s
# [CV] END criterion=gini, max_depth=None, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=42;, score=0.945 total time=   0.8s
# [CV] END criterion=gini, max_depth=None, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=100, random_state=42;, score=0.945 total time=   0.8s
# [CV] END criterion=entropy, max_depth=10, max_features=20, min_samples_leaf=11, min_samples_split=11, n_estimators=200, random_state=42;, score=0.985 total time=   2.6s
# [CV] END criterion=entropy, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=100, random_state=42;, score=0.987 total time=   1.3s
# [CV] END criterion=gini, max_depth=10, max_features=50, min_samples_leaf=5, min_samples_split=5, n_estimators=50, random_state=42;, score=0.934 total time=   0.8s
# [CV] END criterion=gini, max_depth=10, max_features=10, min_samples_leaf=11, min_samples_split=5, n_estimators=300, random_state=42;, score=0.987 total time=   1.6s
# ...
#
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=10, max_features=20, min_samples_leaf=5, min_samples_split=11, n_estimators=10, random_state=42;, score=0.996 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s[CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s[CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
#
#
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s[CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.996 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.940 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
#
# [CV] END criterion=entropy, max_depth=5, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.2s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s[CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.997 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=30, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.996 total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.996 total time=   0.2s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s[CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.985 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s[CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s[CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s[CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
#
#
#
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
#
# 22 	27    	0.979219	0.977183	0.9793  	0.00033993
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.975 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.979 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s[CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=11, min_samples_split=5, n_estimators=10, random_state=42;, score=0.996 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.945 total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=5, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.987 total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s
#
# [CV] END criterion=gini, max_depth=25, max_features=20, min_samples_leaf=5, min_samples_split=5, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s[CV] END criterion=gini, max_depth=50, max_features=20, min_samples_leaf=5, min_samples_split=2, n_estimators=10, random_state=42;, score=0.947 total time=   0.1s

# %%
# Remove bool values from dict
cv.cv_results_.pop('nan_test_score?')

print("Saving CV results")
file_name = "{}_hpo_best_cv.csv".format(prefix)
# with open(os.path.join(model_dir,file_name), 'w') as cvfile:
#     json.dump(cv.cv_results_, cvfile)
cv_test_scores = pd.DataFrame(cv.cv_results_)
cv_test_scores.to_csv(os.path.join(model_dir,file_name), index=False)
print("{} best params: {}".format(prefix, cv.best_params_))
param_name = "{}_hpo_best_param.json".format(prefix)
with open(os.path.join(model_dir,param_name), 'w') as cvfile:
    json.dump(cv.best_params_, cvfile)
print("{} best score: {}".format(prefix, cv.best_score_))
print("Saving best {} estimator".format(prefix))
model_name = "{}_hpo_best.joblib".format(prefix)
dump(cv.best_estimator_, os.path.join(model_dir,model_name))

# %%
y_pred = cv.best_estimator_.predict(X)
custom_scoring_reporting(y_pred, y, definitions, prefix)

# %%
print("Confusion matrix")
cf_matrix = confusion_matrix(y, y_pred)
sns_cf = sns.heatmap(cf_matrix, annot=True, yticklabels=list(definitions), xticklabels=list(definitions))
cf_fig = "{}_cf.png".format(prefix)
sns_cf.figure.savefig(os.path.join(model_dir, cf_fig))

# Extract Feature importance
feat_importances = pd.Series(cv.best_estimator_.feature_importances_, index=list(data.drop('target', axis=1).columns))
featureimp_name = "{}_hpo_best_featureimp.csv".format(prefix)
feat_importances.to_csv(os.path.join(model_dir, featureimp_name), index=True)
# print(feat_importances.head(10))
sorted_feature = feat_importances.sort_values(ascending=True)
# Plot the feature importances of the forest
# plt.figure()
plt.figure(figsize=(10,20), dpi=600)
plt.title("Feature importances")
plt.barh(range(X.shape[1]), sorted_feature,
       color="r", align="center", )
# If you want to define your own labels,
# change indices to a list of labels on the following line.
plt.yticks(range(X.shape[1]), sorted_feature.index)
plt.ylim([-1, X.shape[1]])
plt.show()

# %% [markdown]
# Scoring on holdout or other dataset

# %%
#Creating the dependent variable class
# factor_h = pd.factorize(df_clean['target'])
# df_clean.target = factor_h[0]
# definitions_h = factor_h[1]

# %%
# print("Splitting dataset into data and ground truth ...")
# X_h = df_clean.drop('target', axis=1)
# y_h = df_clean['target']

# Scale
# X_h

# %%
# X_h = scaler.transform(X_h)

# %%
# y_pred_h = cv.best_estimator_.predict(X_h)
#
# custom_scoring_reporting(y_pred_h, y_h, definitions, prefix="rf_holdout")

# %%
# y_pred = cv.best_estimator_.predict(X)
# custom_scoring_reporting(y_pred, y, definitions, prefix)

# jaccard_score(y_h, y_pred_h, average='micro')
# y_pred_h
