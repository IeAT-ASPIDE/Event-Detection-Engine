# %%
"""
PyCaret Experiments Serrano/AUDSOME Phase 1
Gabriel Iuhasz
Anomaly Only
"""
import numpy as np
np.random.seed(42)
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import balanced_accuracy_score, make_scorer, classification_report, accuracy_score, jaccard_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

import xgboost as xgb
# from sklearn.externals import joblib
from joblib import dump, load
import json
import os
import matplotlib.pyplot as plt
import seaborn as sns
from evolutionary_search import EvolutionaryAlgorithmSearchCV
from subprocess import check_output
# %matplotlib inline

# %%
def custom_scoring_reporting(y_pred,
                             y,
                             definitions,
                             prefix):
    """
    Custom function for handling scoring and reporting
    :param y_pred: model predictions
    :param y: ground truth
    :param definitions: variable class definitions (factorize)
    :param prefix: prefix to saved files and images
    :return: 0
    """
    print("Accuracy score is: {}".format(accuracy_score(y, y_pred)))
    print("Ballanced accuracy score is: {}".format(balanced_accuracy_score(y, y_pred)))
    print("Jaccard score (micro): {}".format(jaccard_score(y, y_pred, average='micro')))
    print("Jaccard score (macro): {}".format(jaccard_score(y, y_pred, average='macro')))
    print("Jaccard score (weighted): {}".format(jaccard_score(y, y_pred, average='weighted')))


    print("Full classification report")
    print(classification_report(y, y_pred, target_names=definitions))
    report = classification_report(y, y_pred, output_dict=True)
    df_classification_report = pd.DataFrame(report).transpose()
    classification_rep_name = "{}_classification_rep_best.csv".format(prefix)
    df_classification_report.to_csv(os.path.join(model_dir,classification_rep_name), index=False)


    print("Imbalanced Classification report")
    print(classification_report_imbalanced(y, y_pred, target_names=definitions))
    imb_report = classification_report_imbalanced(y, y_pred, target_names=definitions, output_dict=True)
    df_imb_classification_report = pd.DataFrame(imb_report).transpose()
    classification_imb_rep_name = "{}_imb_classification_rep_best.csv".format(prefix)
    df_imb_classification_report.to_csv(os.path.join(model_dir,classification_imb_rep_name), index=False)

# %% [markdown]
# Common preprocessing for all experiments

# %%
print("Checking files in data location ...")
train_dir = '/Users/Gabriel/Dropbox/Research/ASPIDE/Datasets/ECI Chaos/Distributed Phase 1/finalized/single_node/training'
# train_dir = '/home/gabriel/Research/Aspide/workspace/data_phase'
# train_dir = '/home/gabriel/research/dipet/serrano/data'
print(check_output(["ls", train_dir]).decode("utf8"))
# Out:
# Checking files in data location ...
# data
# df_anomaly.csv
# df_audsome.csv
# df_clean_ausdome_single.csv
# df_clean_single.csv
# models
# processed

# %%
print("Setting paths and datasets")
# Checking if directory exists for data, modells and processed

# data_dir = os.path.join(train_dir,'data')
model_dir = os.path.join(train_dir,'models')
# processed_dir = os.path.join(train_dir,'processed')
# if not os.path.exists(data_dir):
#     os.makedirs(data_dir)
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
# if not os.path.exists(processed_dir):
#     os.makedirs(processed_dir)
# Out:
# Setting paths and datasets

# %%
df_anomaly = pd.read_csv(os.path.join(train_dir,"df_anomaly.csv"))
df_audsome = pd.read_csv(os.path.join(train_dir,"df_audsome.csv"))
df_clean = pd.read_csv(os.path.join(train_dir,"df_clean_single.csv"))
df_clean_audsome = pd.read_csv(os.path.join(train_dir,"df_clean_ausdome_single.csv"))

# Set index as time
df_anomaly.set_index('time', inplace=True)
df_audsome.set_index('time', inplace=True)
df_clean.set_index('time', inplace=True)
df_clean_audsome.set_index('time', inplace=True)

# %%
print("Dataset chosen ...")
data = df_anomaly

# Nice print
nice_y = data['target']
data.shape
# Out:
# Dataset chosen ...
# (5400, 90)

# %%
# Uncomment for removing dummy TODO CHECK if adding back dummy
# data.loc[data.target == "dummy", 'target'] = "0"

#Creating the dependent variable class
factor = pd.factorize(data['target'])
data.target = factor[0]
definitions = factor[1]
# print(data.target.head())
# print(definitions)

# %%
print("Splitting dataset into training and ground truth ...")
X = data.drop('target', axis=1)
y = data['target']
# Out:
# Splitting dataset into training and ground truth ...

# %%
# Plot class distribution
print("Ploting class distribution ..")
plt.figure(dpi=600) #For publication only
pltdist= sns.countplot(nice_y)
pltdist.set_xticklabels(pltdist.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# Ploting class distribution ..

# %%
print("Scaling dataset")
# scaler = StandardScaler()
# scaler = RobustScaler()
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(X_scaled, index=X.index, columns=X.columns) # transform back to df
# Out:
# Scaling dataset

# %%
X['target'] = y
list_columns = list(X.columns.values)
list_columns.pop(-1)
# Out:
# 'target'

# %% [markdown]
# PyCarret Experiments

# %%
# categorical features are detected by mistake, most likely because of low variance features
from pycaret.classification import *
# add target column to scaled dataset
exp_mclf101 = setup(data = X , target = 'target', session_id=1, numeric_features = list_columns, log_experiment = True, experiment_name = 'pycaret_exp_v1')
# Out:
# <style type="text/css">
# #T_52723_row0_col1, #T_52723_row19_col1, #T_52723_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_52723_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52723_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52723_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_52723_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_52723_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_52723_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_52723_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_52723_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_52723_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_52723_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_52723_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_52723_row4_col1" class="data row4 col1" >(5400, 90)</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_52723_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_52723_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_52723_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_52723_row6_col1" class="data row6 col1" >89</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_52723_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_52723_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_52723_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_52723_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_52723_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_52723_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_52723_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_52723_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_52723_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_52723_row11_col1" class="data row11 col1" >(3779, 56)</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_52723_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_52723_row12_col1" class="data row12 col1" >(1621, 56)</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_52723_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_52723_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_52723_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_52723_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_52723_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_52723_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_52723_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_52723_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_52723_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_52723_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_52723_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_52723_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_52723_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_52723_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_52723_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_52723_row20_col1" class="data row20 col1" >pycaret_exp_v1</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_52723_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_52723_row21_col1" class="data row21 col1" >b69a</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_52723_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_52723_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_52723_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_52723_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_52723_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_52723_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_52723_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_52723_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_52723_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_52723_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_52723_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_52723_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_52723_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_52723_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_52723_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_52723_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_52723_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_52723_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_52723_row30_col1" class="data row
# 2022/03/22 14:21:12 INFO mlflow.tracking.fluent: Experiment with name 'pycaret_exp_v1' does not exist. Creating a new experiment.

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_7b97a_ th {
#   text-align: left;
# }
# #T_7b97a_row0_col0, #T_7b97a_row0_col2, #T_7b97a_row1_col0, #T_7b97a_row1_col1, #T_7b97a_row1_col2, #T_7b97a_row1_col3, #T_7b97a_row1_col4, #T_7b97a_row1_col5, #T_7b97a_row1_col6, #T_7b97a_row1_col7, #T_7b97a_row2_col0, #T_7b97a_row2_col1, #T_7b97a_row2_col2, #T_7b97a_row2_col3, #T_7b97a_row2_col4, #T_7b97a_row2_col5, #T_7b97a_row2_col6, #T_7b97a_row2_col7, #T_7b97a_row3_col0, #T_7b97a_row3_col1, #T_7b97a_row3_col3, #T_7b97a_row3_col4, #T_7b97a_row3_col5, #T_7b97a_row3_col6, #T_7b97a_row3_col7, #T_7b97a_row4_col0, #T_7b97a_row4_col1, #T_7b97a_row4_col2, #T_7b97a_row4_col3, #T_7b97a_row4_col4, #T_7b97a_row4_col5, #T_7b97a_row4_col6, #T_7b97a_row4_col7, #T_7b97a_row5_col0, #T_7b97a_row5_col1, #T_7b97a_row5_col2, #T_7b97a_row5_col3, #T_7b97a_row5_col4, #T_7b97a_row5_col5, #T_7b97a_row5_col6, #T_7b97a_row5_col7, #T_7b97a_row6_col0, #T_7b97a_row6_col1, #T_7b97a_row6_col2, #T_7b97a_row6_col3, #T_7b97a_row6_col4, #T_7b97a_row6_col5, #T_7b97a_row6_col6, #T_7b97a_row6_col7, #T_7b97a_row7_col0, #T_7b97a_row7_col1, #T_7b97a_row7_col2, #T_7b97a_row7_col3, #T_7b97a_row7_col4, #T_7b97a_row7_col5, #T_7b97a_row7_col6, #T_7b97a_row7_col7, #T_7b97a_row8_col0, #T_7b97a_row8_col1, #T_7b97a_row8_col2, #T_7b97a_row8_col3, #T_7b97a_row8_col4, #T_7b97a_row8_col5, #T_7b97a_row8_col6, #T_7b97a_row8_col7, #T_7b97a_row9_col0, #T_7b97a_row9_col1, #T_7b97a_row9_col2, #T_7b97a_row9_col3, #T_7b97a_row9_col4, #T_7b97a_row9_col5, #T_7b97a_row9_col6, #T_7b97a_row9_col7, #T_7b97a_row10_col0, #T_7b97a_row10_col1, #T_7b97a_row10_col2, #T_7b97a_row10_col3, #T_7b97a_row10_col4, #T_7b97a_row10_col5, #T_7b97a_row10_col6, #T_7b97a_row10_col7, #T_7b97a_row11_col0, #T_7b97a_row11_col1, #T_7b97a_row11_col2, #T_7b97a_row11_col3, #T_7b97a_row11_col4, #T_7b97a_row11_col5, #T_7b97a_row11_col6, #T_7b97a_row11_col7, #T_7b97a_row12_col0, #T_7b97a_row12_col1, #T_7b97a_row12_col2, #T_7b97a_row12_col3, #T_7b97a_row12_col4, #T_7b97a_row12_col5, #T_7b97a_row12_col6, #T_7b97a_row12_col7, #T_7b97a_row13_col0, #T_7b97a_row13_col1, #T_7b97a_row13_col2, #T_7b97a_row13_col3, #T_7b97a_row13_col4, #T_7b97a_row13_col5, #T_7b97a_row13_col6, #T_7b97a_row13_col7, #T_7b97a_row14_col0, #T_7b97a_row14_col1, #T_7b97a_row14_col2, #T_7b97a_row14_col3, #T_7b97a_row14_col4, #T_7b97a_row14_col5, #T_7b97a_row14_col6, #T_7b97a_row14_col7, #T_7b97a_row15_col0, #T_7b97a_row15_col1, #T_7b97a_row15_col2, #T_7b97a_row15_col3, #T_7b97a_row15_col4, #T_7b97a_row15_col5, #T_7b97a_row15_col6, #T_7b97a_row15_col7 {
#   text-align: left;
# }
# #T_7b97a_row0_col1, #T_7b97a_row0_col3, #T_7b97a_row0_col4, #T_7b97a_row0_col5, #T_7b97a_row0_col6, #T_7b97a_row0_col7, #T_7b97a_row3_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7b97a_row0_col8, #T_7b97a_row1_col8, #T_7b97a_row2_col8, #T_7b97a_row3_col8, #T_7b97a_row4_col8, #T_7b97a_row5_col8, #T_7b97a_row6_col8, #T_7b97a_row7_col8, #T_7b97a_row8_col8, #T_7b97a_row9_col8, #T_7b97a_row10_col8, #T_7b97a_row13_col8, #T_7b97a_row14_col8, #T_7b97a_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_
level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_7b97a_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_7b97a_row5_col1" class="data row5 col1" >0.9942</td>
#       <td id="T_7b97a_row5_col2" class="data row5 col2" >0.9898</td>
#       <td id="T_7b97a_row5_col3" class="data row5 col3" >0.9469</td>
#       <td id="T_7b97a_row5_col4" class="data row5 col4" >0.9945</td>
#       <td id="T_7b97a_row5_col5" class="data row5

# %%
best
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
ct = create_model('catboost')
# Out:
# <style type="text/css">
# #T_1a33f_row10_col0, #T_1a33f_row10_col1, #T_1a33f_row10_col2, #T_1a33f_row10_col3, #T_1a33f_row10_col4, #T_1a33f_row10_col5, #T_1a33f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1a33f_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Split</th>
#       <th class="index_name level1" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a33f_level0_row0" class="row_heading level0 row0" rowspan="12">CV-Val</th>
#       <th id="T_1a33f_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_1a33f_row0_col0" class="data row0 col0" >0.9974</td>
#       <td id="T_1a33f_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_1a33f_row0_col2" class="data row0 col2" >0.9800</td>
#       <td id="T_1a33f_row0_col3" class="data row0 col3" >0.9975</td>
#       <td id="T_1a33f_row0_col4" class="data row0 col4" >0.9973</td>
#       <td id="T_1a33f_row0_col5" class="data row0 col5" >0.9874</td>
#       <td id="T_1a33f_row0_col6" class="data row0 col6" >0.9874</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_1a33f_row1_col0" class="data row1 col0" >0.9894</td>
#       <td id="T_1a33f_row1_col1" class="data row1 col1" >0.9941</td>
#       <td id="T_1a33f_row1_col2" class="data row1 col2" >0.9126</td>
#       <td id="T_1a33f_row1_col3" class="data row1 col3" >0.9905</td>
#       <td id="T_1a33f_row1_col4" class="data row1 col4" >0.9897</td>
#       <td id="T_1a33f_row1_col5" class="data row1 col5" >0.9485</td>
#       <td id="T_1a33f_row1_col6" class="data row1 col6" >0.9489</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_1a33f_row2_col0" class="data row2 col0" >0.9921</td>
#       <td id="T_1a33f_row2_col1" class="data row2 col1" >0.9998</td>
#       <td id="T_1a33f_row2_col2" class="data row2 col2" >0.9407</td>
#       <td id="T_1a33f_row2_col3" class="data row2 col3" >0.9923</td>
#       <td id="T_1a33f_row2_col4" class="data row2 col4" >0.9921</td>
#       <td id="T_1a33f_row2_col5" class="data row2 col5" >0.9626</td>
#       <td id="T_1a33f_row2_col6" class="data row2 col6" >0.9627</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_1a33f_row3_col0" class="data row3 col0" >0.9921</td>
#       <td id="T_1a33f_row3_col1" class="data row3 col1" >0.9997</td>
#       <td id="T_1a33f_row3_col2" class="data row3 col2" >0.9042</td>
#       <td id="T_1a33f_row3_col3" class="data row3 col3" >0.9923</td>
#       <td id="T_1a33f_row3_col4" class="data row3 col4" >0.9920</td>
#       <td id="T_1a33f_row3_col5" class="data row3 col5" >0.9622</td>
#       <td id="T_1a33f_row3_col6" class="data row3 col6" >0.9622</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_1a33f_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_1a33f_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_1a33f_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_1a33f_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_1a33f_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_1a33f_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_1a33f_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level1_row5" class="row_heading level1 row5" >5</th>
#       <td id="T_1a33f_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_1a33f_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_1a33f_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_1a33f_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_1a33f_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_1a33f_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_1a33f_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level1_row6" class="row_heading level1 row6" >6</th>
#       <td id="T_1a33f_row6_col0" class="data row6 col0" >0.9947</td>
#       <td id="T_1a33f_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_1a33f_row6_col2" class="data row6 col2" >0.9429</td>
#       <td id="T_1a33f_row6_col3" class="data row6 col3" >0.9947</td>
#       <td id="T_1a33f_row6_col4" class="data row6 col4" >0.9943</td>
#       <td id="T_1a33f_row6_col5" class="data row6 col5" >0.9742</td>
#       <td id="T_1a33f_row6_col6" class="data row6 col6" >0.9746</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level1_row7" class="row_heading level1 row7" >7</th>
#       <td id="T_1a33f_row7_col0" class="data row7 col0" >0.9947</td>
#       <td id="T_1a33f_row7_col1" class="data row7 col1" >0.9977</td>
#       <td id="T_1a33f_row7_col2" class="data row7 col2" >0.9709</td>
#       <td id="T_1a33f_row7_col3" class="data row7 col3" >0.9947</td>
#       <td id="T_1a33f_row7_col4" class="data row7 col4" >0.9946</td>
#       <td id="T_1a33f_row7_col5" class="data row7 col5" >0.9743</td>
#       <td id="T_1a33f_row7_col6" class="data row7 col6" >0.9746</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level1_row8" class="row_heading level1 row8" >8</th>
#       <td id="T_1a33f_row8_col0" class="data row8 col0" >0.9974</td>
#       <td id="T_1a33f_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_1a33f_row8_col2" class="data row8 col2" >0.9800</td>
#       <td id="T_1a33f_row8_col3" class="data row8 col3" >0.9974</td>
#       <td id="T_1a33f_row8_col4" class="data row8 col4" >0.9973</td>
#       <td id="T_1a33f_row8_col5" class="data row8 col5" >0.9875</td>
#       <td id="T_1a33f_row8_col6" class="data row8 col6" >0.9876</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level1_row9" class="row_heading level1 row9" >9</th>
#       <td id="T_1a33f_row9_col0" class="data row9 col0" >0.9841</td>
#       <td id="T_1a33f_row9_col1" class="data row9 col1" >0.9988</td>
#       <td id="T_1a33f_row9_col2" class="data row9 col2" >0.8981</td>
#       <td id="T_1a33f_row9_col3" class="data row9 col3" >0.9858</td>
#       <td id="T_1a33f_row9_col4" class="data row9 col4" >0.9843</td>
#       <td id="T_1a33f_row9_col5" class="data row9 col5" >0.9252</td>
#       <td id="T_1a33f_row9_col6" class="data row9 col6" >0.9254</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level1_row10" class="row_heading level1 row10" >Mean</th>
#       <td id="T_1a33f_row10_col0" class="data row10 col0" >0.9942</td>
#       <td id="T_1a33f_row10_col1" class="data row10 col1" >0.9990</td>
#       <td id="T_1a33f_row10_col2" class="data row10 col2" >0.9529</td>
#       <td id="T_1a33f_row10_col3" class="data row10 col3" >0.9945</td>
#       <td id="T_1a33f_row10_col4" class="data row10 col4" >0.9942</td>
#       <td id="T_1a33f_row10_col5" class="data row10 col5" >0.9722</td>
#       <td id="T_1a33f_row10_col6" class="data row10 col6" >0.9723</td>
#     </tr>
#     <tr>
#       <th id="T_1a33f_level1_row11" class="row_heading level1 row11" >Std</th>
#       <td id="T_1a33f_row11_col0" class="data row11 col0" >0.0047</td>
#       <td id="T_1a33f_row11_col1" class="data row11 col1" >0.0018</td>
#       <td id="T_1a33f_row11_col2" class="data row11 col2" >0.0367</td>
#       <td id="T_1a33f_row11_col3" class="data row11 col3" >0.0042</td>
#       <td id="T_1a33f_row11_c

# %%
et = create_model('et')
# Out:
# <style type="text/css">
# #T_4cf2c_row10_col0, #T_4cf2c_row10_col1, #T_4cf2c_row10_col2, #T_4cf2c_row10_col3, #T_4cf2c_row10_col4, #T_4cf2c_row10_col5, #T_4cf2c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_4cf2c_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Split</th>
#       <th class="index_name level1" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4cf2c_level0_row0" class="row_heading level0 row0" rowspan="12">CV-Val</th>
#       <th id="T_4cf2c_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_4cf2c_row0_col0" class="data row0 col0" >0.9974</td>
#       <td id="T_4cf2c_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_4cf2c_row0_col2" class="data row0 col2" >0.9800</td>
#       <td id="T_4cf2c_row0_col3" class="data row0 col3" >0.9975</td>
#       <td id="T_4cf2c_row0_col4" class="data row0 col4" >0.9973</td>
#       <td id="T_4cf2c_row0_col5" class="data row0 col5" >0.9874</td>
#       <td id="T_4cf2c_row0_col6" class="data row0 col6" >0.9874</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2c_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_4cf2c_row1_col0" class="data row1 col0" >0.9921</td>
#       <td id="T_4cf2c_row1_col1" class="data row1 col1" >0.9882</td>
#       <td id="T_4cf2c_row1_col2" class="data row1 col2" >0.9213</td>
#       <td id="T_4cf2c_row1_col3" class="data row1 col3" >0.9921</td>
#       <td id="T_4cf2c_row1_col4" class="data row1 col4" >0.9920</td>
#       <td id="T_4cf2c_row1_col5" class="data row1 col5" >0.9618</td>
#       <td id="T_4cf2c_row1_col6" class="data row1 col6" >0.9619</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2c_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_4cf2c_row2_col0" class="data row2 col0" >0.9974</td>
#       <td id="T_4cf2c_row2_col1" class="data row2 col1" >0.9986</td>
#       <td id="T_4cf2c_row2_col2" class="data row2 col2" >0.9500</td>
#       <td id="T_4cf2c_row2_col3" class="data row2 col3" >0.9976</td>
#       <td id="T_4cf2c_row2_col4" class="data row2 col4" >0.9972</td>
#       <td id="T_4cf2c_row2_col5" class="data row2 col5" >0.9874</td>
#       <td id="T_4cf2c_row2_col6" class="data row2 col6" >0.9874</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2c_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_4cf2c_row3_col0" class="data row3 col0" >0.9947</td>
#       <td id="T_4cf2c_row3_col1" class="data row3 col1" >0.9985</td>
#       <td id="T_4cf2c_row3_col2" class="data row3 col2" >0.9327</td>
#       <td id="T_4cf2c_row3_col3" class="data row3 col3" >0.9949</td>
#       <td id="T_4cf2c_row3_col4" class="data row3 col4" >0.9948</td>
#       <td id="T_4cf2c_row3_col5" class="data row3 col5" >0.9750</td>
#       <td id="T_4cf2c_row3_col6" class="data row3 col6" >0.9751</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2c_level1_row4" class="row_heading level1 row4" >4</th>
#       <td id="T_4cf2c_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_4cf2c_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_4cf2c_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_4cf2c_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_4cf2c_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_4cf2c_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_4cf2c_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2c_level1_row5" class="row_heading level1 row5" >5</th>
#       <td id="T_4cf2c_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_4cf2c_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_4cf2c_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_4cf2c_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_4cf2c_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_4cf2c_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_4cf2c_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2c_level1_row6" class="row_heading level1 row6" >6</th>
#       <td id="T_4cf2c_row6_col0" class="data row6 col0" >0.9974</td>
#       <td id="T_4cf2c_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_4cf2c_row6_col2" class="data row6 col2" >0.9714</td>
#       <td id="T_4cf2c_row6_col3" class="data row6 col3" >0.9974</td>
#       <td id="T_4cf2c_row6_col4" class="data row6 col4" >0.9973</td>
#       <td id="T_4cf2c_row6_col5" class="data row6 col5" >0.9873</td>
#       <td id="T_4cf2c_row6_col6" class="data row6 col6" >0.9874</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2c_level1_row7" class="row_heading level1 row7" >7</th>
#       <td id="T_4cf2c_row7_col0" class="data row7 col0" >0.9947</td>
#       <td id="T_4cf2c_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_4cf2c_row7_col2" class="data row7 col2" >0.9709</td>
#       <td id="T_4cf2c_row7_col3" class="data row7 col3" >0.9952</td>
#       <td id="T_4cf2c_row7_col4" class="data row7 col4" >0.9948</td>
#       <td id="T_4cf2c_row7_col5" class="data row7 col5" >0.9745</td>
#       <td id="T_4cf2c_row7_col6" class="data row7 col6" >0.9747</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2c_level1_row8" class="row_heading level1 row8" >8</th>
#       <td id="T_4cf2c_row8_col0" class="data row8 col0" >0.9974</td>
#       <td id="T_4cf2c_row8_col1" class="data row8 col1" >0.9998</td>
#       <td id="T_4cf2c_row8_col2" class="data row8 col2" >0.9800</td>
#       <td id="T_4cf2c_row8_col3" class="data row8 col3" >0.9974</td>
#       <td id="T_4cf2c_row8_col4" class="data row8 col4" >0.9973</td>
#       <td id="T_4cf2c_row8_col5" class="data row8 col5" >0.9875</td>
#       <td id="T_4cf2c_row8_col6" class="data row8 col6" >0.9876</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2c_level1_row9" class="row_heading level1 row9" >9</th>
#       <td id="T_4cf2c_row9_col0" class="data row9 col0" >0.9867</td>
#       <td id="T_4cf2c_row9_col1" class="data row9 col1" >0.9984</td>
#       <td id="T_4cf2c_row9_col2" class="data row9 col2" >0.8987</td>
#       <td id="T_4cf2c_row9_col3" class="data row9 col3" >0.9875</td>
#       <td id="T_4cf2c_row9_col4" class="data row9 col4" >0.9867</td>
#       <td id="T_4cf2c_row9_col5" class="data row9 col5" >0.9370</td>
#       <td id="T_4cf2c_row9_col6" class="data row9 col6" >0.9370</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2c_level1_row10" class="row_heading level1 row10" >Mean</th>
#       <td id="T_4cf2c_row10_col0" class="data row10 col0" >0.9958</td>
#       <td id="T_4cf2c_row10_col1" class="data row10 col1" >0.9983</td>
#       <td id="T_4cf2c_row10_col2" class="data row10 col2" >0.9605</td>
#       <td id="T_4cf2c_row10_col3" class="data row10 col3" >0.9960</td>
#       <td id="T_4cf2c_row10_col4" class="data row10 col4" >0.9957</td>
#       <td id="T_4cf2c_row10_col5" class="data row10 col5" >0.9798</td>
#       <td id="T_4cf2c_row10_col6" class="data row10 col6" >0.9799</td>
#     </tr>
#     <tr>
#       <th id="T_4cf2c_level1_row11" class="row_heading level1 row11" >Std</th>
#       <td id="T_4cf2c_row11_col0" class="data row11 col0" >0.0038</td>
#       <td id="T_4cf2c_row11_col1" class="data row11 col1" >0.0035</td>
#       <td id="T_4cf2c_row11_col2" class="data row11 col2" >0.0322</td>
#       <td id="T_4cf2c_row11_col3" class="data row11 col3" >0.0036</td>
#       <td id="T_4cf2c_row11_c

# %%
p_et = predict_model(et)
# y_pred = et.predict(X)

custom_scoring_reporting(p_et['Label'], p_et['target'], definition=definition, prefix='et_anomaly')
# Out:
# <style type="text/css">
# </style>
# <table id="T_72982_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72982_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72982_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_72982_row0_col1" class="data row0 col1" >0.9969</td>
#       <td id="T_72982_row0_col2" class="data row0 col2" >0.9994</td>
#       <td id="T_72982_row0_col3" class="data row0 col3" >0.9720</td>
#       <td id="T_72982_row0_col4" class="data row0 col4" >0.9971</td>
#       <td id="T_72982_row0_col5" class="data row0 col5" >0.9969</td>
#       <td id="T_72982_row0_col6" class="data row0 col6" >0.9848</td>
#       <td id="T_72982_row0_col7" class="data row0 col7" >0.9848</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [67], in <module>
#       1 p_et = predict_model(et)
#       2 # y_pred = et.predict(X)
# ----> 4 custom_scoring_reporting(p_et['Label'], p_et['target'], definition=definition, prefix='et_anomaly')
#
# NameError: name 'definition' is not defined

# %%
custom_scoring_reporting(y_pred, y, definition=definition, prefix='et_anomaly')

# %%
interpret_model(best)

# %%
# finalize the model
final_best = finalize_model(best)

# %%
# save model to disk
save_model(final_best, 'anomaly_only')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['node_context_switches_total_10.251.0.114:9100',
#                                                            'node_cpu_seconds_total_10.251.0.114:9100',
#                                                            'node_disk_io_time_seconds_total_10.251.0.114:9100',
#                                                            'node_disk_io_time_weigh...
#                   ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                        class_weight=None, criterion='gini',
#                                        max_depth=None, max_features='auto',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_impurity_split=None,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        n_estimators